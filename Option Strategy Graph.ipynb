# %%
import optionStrategy
import option

# %%
## Call
strats = ["Long 1 100 Call 2.70"]
min = 80
max = 120
reload(optionStrategy)
optionStrategy.plotStrategy(strats, min, max)

# %%
## Put
strats = ["Long 1 100 Put 2.70"]
min = 80
max = 120
reload(optionStrategy)
optionStrategy.plotStrategy(strats, min, max)

# %%
## Short Call
strats = ["Short 1 100 Call 2.70"]
min = 80
max = 120
reload(optionStrategy)
optionStrategy.plotStrategy(strats, min, max)

# %%
## Short Put
strats = ["Short 1 100 Put 2.70"]
min = 80
max = 120
reload(optionStrategy)
optionStrategy.plotStrategy(strats, min, max)

# %%
## Strategy 1
strats = ["Long 1 100 Call 2.70", "Long 1 100 Put 3.7"]
min = 80
max = 120
reload(optionStrategy)
optionStrategy.plotStrategy(strats, min, max)

# %%
## Strategy 2
strats = ["Short 1 100 Call 2.70", "Short 1 100 Put 3.7"]
min = 80
max = 120
reload(optionStrategy)
optionStrategy.plotStrategy(strats, min, max)

# %%
## Strategy 3
strats = ["Short 1 95 Call 1.55", "Short 1 105 Put 1.15"]
min = 80
max = 120
reload(optionStrategy)
optionStrategy.plotStrategy(strats, min, max)

# %%
## Strategy 4
strats = ["Long 1 90 Call 9.35", "Short 1 100 Call 2.7"]
min = 85
max = 115
reload(optionStrategy)
optionStrategy.plotStrategy(strats, min, max)

# %%
## TCS
#strats = ["Long 30 Stock 1300", "Short 250 1560 Call 32"]
strats = ["Short 250 1560 Call 32", "Short 250 1600 Put 20"]
min = 0.95
max = 1.05
reload(optionStrategy)
reload(option)
optionStrategy.plotStrategy(strats, min, max)
optionStrategy.listStrategy(strats, [1500,1700])
delta1 = option.Option(1648, 1560, 0.10, 10.0/250, 0.4).get_delta(100.0)
delta2 = option.Option(1648, 1600, 0.10, 10.0/250, 0.4).get_delta(20.0)
print delta2-delta1
# Out:
# 1500 	-12000.0
# 1700 	-22000.0
# 1560.0 	3000.0
# 1600.0 	3000.0
# -0.00113681225208

# %%
## Strategy 4
strats = ["Long 1000 Stock 361.75", "Short 1000 380 Call 5.5"]
min = 0
max = 2000
reload(optionStrategy)
optionStrategy.plotStrategy(strats, min, max)

# %%
## Strategy 4
strats = ["Short 1000 350 Call 4.4"]
min = 0.98
max = 1.02
reload(optionStrategy)
optionStrategy.plotStrategy(strats, min, max)

# %%
## Strategy 4
strats = ["Short 250 1480 Call 10.0"]
min = 0.98
max = 1.03
reload(optionStrategy)
optionStrategy.plotStrategy(strats, min, max)
# Out:
# 1200 	2500.0
# 1700 	-52500.0
# 1480.0 	2500.0

# %%
strats = ["Short 50 5900 Put 74.5", "Long 50 5800 Put 51.3"]
reload(optionStrategy)
reload(option)
optionStrategy.plotStrategy(strats, 0.9, 1.1)
x = option.Option(6029,5900, 0.1,30.0/250,0.1925)
x.print_greeks(172, 'C')
# Out:
# Delta : 0.455787276954
# Theta : -1.02313880591
# Vega  : 50.6447402297
# Vol   : 28.6224365234

# %%
strats = ["Short 50 6000 Put 74.5", "Long 50 5800 Put 51.3"]
reload(optionStrategy)
reload(option)
#optionStrategy.plotStrategy(strats, 0.9, 1.1)
x = option.Option(6029,6000, 0.1,29.0/250,0.1472)
x.print_greeks(74.5, 'P')
# Out:
# 250.0
# 125.0
# 62.5
# 93.75
# 109.375
# 117.1875
# 113.28125
# 111.328125
# 110.3515625
# 109.86328125
# 110.107421875
# 109.985351562
# 109.924316406
# 109.954833984
# Delta : -0.43633430518
# Theta : 1.08714958527
# Vega  : 50.300571795
# Vol   : 10.9954833984

# %%
strats = ["Short 50 5900 Put 74.5", "Long 50 5800 Put 51.3"]
reload(optionStrategy)
reload(option)
#optionStrategy.plotStrategy(strats, 0.9, 1.1)
x = option.Option(6000,6029, 0.1,40.0/356,0.1472)
print x.get_call()
x.print_greeks(172.5, 'C')
x.print_greeks(105, 'P')
print x.get_put()
# Out:
# 171.917497703
# Delta : 0.636871690392
# Theta : -2.36599383398
# Vega  : 7.58837313523
# Vol   : 14.8193359375
# Delta : -0.363884644882
# Theta : -1.06847574165
# Vega  : 7.73094517084
# Vol   : 18.5180664062
# 104.992450293
