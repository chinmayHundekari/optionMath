# %%
import os
import csvParser
import csv

# %%
reload(csvParser)
fi = open('TCS_CE_14-04-2013_TO_12-07-2013.csv', 'rb')
reader = csv.reader(fi)    
strike = 1400
optdict = csvParser.getStrike(reader,strike)
#csvParser.ivandcloseGraph(optdict, strike)
csvParser.ivandstdGraph(optdict, strike)

# %%
reload(csvParser)
fi = open('OPTSTK_TCS_PE_21-04-2013_TO_19-07-2013.csv', 'rb')
reader = csv.reader(fi)    
strike = 1400
optdict = csvParser.getStrike(reader,strike)
#csvParser.ivandcloseGraph(optdict, strike)
csvParser.ivandstdGraph(optdict, strike)
# Out:
# 9.80223897326
# [ 1556.85  1567.35  1543.4 ]
